# %%
from pyspark.sql import SparkSession

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("parq_data") \
    .getOrCreate()

# %%
df=spark.read \
    .option('header','true') \
    .option('inferSchema','true') \
    .csv('myFiles/Mental_Health_and_Social_Media_Balance_Dataset.csv')

# %%
df.count()
# Out:
# 500

# %%
import os

os.listdir("myFiles")
# Out:
# ['.ipynb_checkpoints',
#  'Mental_Health_and_Social_Media_Balance_Dataset.csv',
#  'Mental_Health.parquet']

# %%
df = spark.read.csv("myFiles/Mental_Health_and_Social_Media_Balance_Dataset.csv", header=True, inferSchema=True)

# %%
df.write.parquet('myFiles/Mental_Health.parquet', mode='overwrite')

# %%
df.count()
# Out:
# 500

# %%
df = spark.read.parquet("myFiles/Mental_Health.parquet")
df.show(5)
# Out:
# +-------+---+------+----------------------+-------------------+------------------+-------------------------+------------------------+---------------------+---------------------+
# |User_ID|Age|Gender|Daily_Screen_Time(hrs)|Sleep_Quality(1-10)|Stress_Level(1-10)|Days_Without_Social_Media|Exercise_Frequency(week)|Social_Media_Platform|Happiness_Index(1-10)|
# +-------+---+------+----------------------+-------------------+------------------+-------------------------+------------------------+---------------------+---------------------+
# |   U001| 44|  Male|                   3.1|                7.0|               6.0|                      2.0|                     5.0|             Facebook|                 10.0|
# |   U002| 30| Other|                   5.1|                7.0|               8.0|                      5.0|                     3.0|             LinkedIn|                 10.0|
# |   U003| 23| Other|                   7.4|                6.0|               7.0|                      1.0|                     3.0|              YouTube|                  6.0|
# |   U004| 36|Female|                   5.7|                7.0|               8.0|                      1.0|                     1.0|               TikTok|                  8.0|
# |   U005| 34|Female|                   7.0|                4.0|               7.0|                      5.0|                     1.0|          X (Twitter)|                  8.0|
# +-------+---+------+----------------------+-------------------+------------------+-------------------------+------------------------+---------------------+---------------------+
# only showing top 5 rows

# %%
df = df.withColumnRenamed("Daily_Screen_Time(hrs)", "Daily_Screen_Time") \
       .withColumnRenamed("Sleep_Quality(1-10)", "Sleep_Quality") \
       .withColumnRenamed("Stress_Level(1-10)", "Stress_Level") \
       .withColumnRenamed("Exercise_Frequency(week)", "Exercise_Frequency") \
       .withColumnRenamed("Happiness_Index(1-10)", "Happiness_Index")
       
from pyspark.sql import Row

new_row = spark.createDataFrame([Row(
    User_ID="U501",
    Age=25,
    Gender="Male",
    Daily_Screen_Time=2,
    Sleep_Quality=8,
    Stress_Level=7,
    Days_Without_Social_Media=1.0,
    Exercise_Frequency=1,
    Social_Media_Platform="Twitter",
    Happiness_Index=1
)])

df_appended = df.union(new_row)
df_appended.show()
# Out:
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# |User_ID|Age|Gender|Daily_Screen_Time|Sleep_Quality|Stress_Level|Days_Without_Social_Media|Exercise_Frequency|Social_Media_Platform|Happiness_Index|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# |   U001| 44|  Male|              3.1|          7.0|         6.0|                      2.0|               5.0|             Facebook|           10.0|
# |   U002| 30| Other|              5.1|          7.0|         8.0|                      5.0|               3.0|             LinkedIn|           10.0|
# |   U003| 23| Other|              7.4|          6.0|         7.0|                      1.0|               3.0|              YouTube|            6.0|
# |   U004| 36|Female|              5.7|          7.0|         8.0|                      1.0|               1.0|               TikTok|            8.0|
# |   U005| 34|Female|              7.0|          4.0|         7.0|                      5.0|               1.0|          X (Twitter)|            8.0|
# |   U006| 38|  Male|              6.6|          5.0|         7.0|                      4.0|               3.0|             LinkedIn|            8.0|
# |   U007| 26|Female|              7.8|          4.0|         8.0|                      2.0|               0.0|               TikTok|            7.0|
# |   U008| 26|Female|              7.4|          5.0|         6.0|                      1.0|               4.0|            Instagram|            7.0|
# |   U009| 39|  Male|              4.7|          7.0|         7.0|                      6.0|               1.0|              YouTube|            9.0|
# |   U010| 39|Female|              6.6|          6.0|         8.0|                      0.0|               2.0|             Facebook|            7.0|
# |   U011| 18|Female|              2.8|          7.0|         6.0|                      2.0|               0.0|            Instagram|            7.0|
# |   U012| 37| Other|              5.4|          5.0|         7.0|                      3.0|               2.0|            Instagram|            9.0|
# |   U013| 17|Female|              7.0|          7.0|        10.0|                      7.0|               1.0|              YouTube|            8.0|
# |   U014| 39|Female|              5.7|          5.0|         7.0|                      4.0|               0.0|             Facebook|            8.0|
# |   U015| 45|  Male|              6.3|          7.0|         7.0|                      4.0|               3.0|          X (Twitter)|            9.0|
# |   U016| 17|Female|              5.1|          7.0|         6.0|                      2.0|               5.0|             LinkedIn|           10.0|
# |   U017| 36|Female|              7.5|          5.0|         8.0|                      4.0|               4.0|             Facebook|            7.0|
# |   U018| 48|  Male|              5.4|          6.0|         4.0|                      3.0|               4.0|               TikTok|           10.0|
# |   U019| 27|  Male|              4.7|          6.0|         6.0|                      0.0|               2.0|            Instagram|            9.0|
# |   U020| 37|  Male|              7.1|          6.0|         6.0|                      5.0|               4.0|               TikTok|           10.0|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# only showing top 20 rows

# %%
df_appended.select("User_ID","Age").show(501)
# Out:
# +-------+---+
# |User_ID|Age|
# +-------+---+
# |   U001| 44|
# |   U002| 30|
# |   U003| 23|
# |   U004| 36|
# |   U005| 34|
# |   U006| 38|
# |   U007| 26|
# |   U008| 26|
# |   U009| 39|
# |   U010| 39|
# |   U011| 18|
# |   U012| 37|
# |   U013| 17|
# |   U014| 39|
# |   U015| 45|
# |   U016| 17|
# |   U017| 36|
# |   U018| 48|
# |   U019| 27|
# |   U020| 37|
# |   U021| 40|
# |   U022| 42|
# |   U023| 43|
# |   U024| 31|
# |   U025| 30|
# |   U026| 18|
# |   U027| 22|
# |   U028| 36|
# |   U029| 24|
# |   U030| 33|
# |   U031| 19|
# |   U032| 40|
# |   U033| 29|
# |   U034| 24|
# |   U035| 41|
# |   U036| 17|
# |   U037| 35|
# |   U038| 43|
# |   U039| 22|
# |   U040| 23|
# |   U041| 29|
# |   U042| 32|
# |   U043| 19|
# |   U044| 17|
# |   U045| 21|
# |   U046| 19|
# |   U047| 44|
# |   U048| 33|
# |   U049| 41|
# |   U050| 49|
# |   U051| 25|
# |   U052| 29|
# |   U053| 46|
# |   U054| 30|
# |   U055| 23|
# |   U056| 29|
# |   U057| 38|
# |   U058| 36|
# |   U059| 31|
# |   U060| 33|
# |   U061| 39|
# |   U062| 41|
# |   U063| 40|
# |   U064| 44|
# |   U065| 30|
# |   U066| 16|
# |   U067| 40|
# |   U068| 22|
# |   U069| 24|
# |   U070| 39|
# |   U071| 16|
# |   U072| 23|
# |   U073| 39|
# |   U074| 26|
# |   U075| 32|
# |   U076| 23|
# |   U077| 48|
# |   U078| 20|
# |   U079| 43|
# |   U080| 22|
# |   U081| 24|
# |   U082| 23|
# |   U083| 27|
# |   U084| 49|
# |   U085| 48|
# |   U086| 38|
# |   U087| 39|
# |   U088| 37|
# |   U089| 42|
# |   U090| 16|
# |   U091| 29|
# |   U092| 18|
# |   U093| 16|
# |   U094| 20|
# |   U095| 41|
# |   U096| 29|
# |   U097| 42|
# |   U098| 24|
# |   U099| 30|
# |   U100| 30|
# |   U101| 41|
# |   U102| 28|
# |   U103| 47|
# |   U104| 47|
# |   U105| 19|
# |   U106| 45|
# |   U107| 38|
# |   U108| 30|
# |   U109| 44|
# |   U110| 28|
# |   U111| 47|
# |   U112| 22|
# |   U113| 37|
# |   U114| 43|
# |   U115| 17|
# |   U116| 21|
# |   U117| 43|
# |   U118| 43|
# |   U119| 35|
# |   U120| 45|
# |   U121| 26|
# |   U122| 43|
# |   U123| 40|
# |   U124| 48|
# |   U125| 16|
# |   U126| 42|
# |   U127| 28|
# |   U128| 18|
# |   U129| 21|
# |   U130| 23|
# |   U131| 42|
# |   U132| 24|
# |   U133| 48|
# |   U134| 39|
# |   U135| 30|
# |   U136| 47|
# |   U137| 47|
# |   U138| 39|
# |   U139| 27|
# |   U140| 17|
# |   U141| 18|
# |   U142| 32|
# |   U143| 17|
# |   U144| 17|
# |   U145| 43|
# |   U146| 38|
# |   U147| 47|
# |   U148| 48|
# |   U149| 16|
# |   U150| 34|
# |   U151| 17|
# |   U152| 41|
# |   U153| 47|
# |   U154| 21|
# |   U155| 47|
# |   U156| 19|
# |   U157| 26|
# |   U158| 32|
# |   U159| 39|
# |   U160| 20|
# |   U161| 49|
# |   U162| 21|
# |   U163| 37|
# |   U164| 26|
# |   U165| 31|
# |   U166| 48|
# |   U167| 24|
# |   U168| 21|
# |   U169| 31|
# |   U170| 44|
# |   U171| 18|
# |   U172| 35|
# |   U173| 34|
# |   U174| 41|
# |   U175| 18|
# |   U176| 34|
# |   U177| 35|
# |   U178| 47|
# |   U179| 22|
# |   U180| 48|
# |   U181| 33|
# |   U182| 16|
# |   U183| 26|
# |   U184| 43|
# |   U185| 40|
# |   U186| 38|
# |   U187| 46|
# |   U188| 45|
# |   U189| 22|
# |   U190| 31|
# |   U191| 41|
# |   U192| 17|
# |   U193| 16|
# |   U194| 27|
# |   U195| 20|
# |   U196| 47|
# |   U197| 24|
# |   U198| 34|
# |   U199| 31|
# |   U200| 18|
# |   U201| 35|
# |   U202| 39|
# |   U203| 48|
# |   U204| 39|
# |   U205| 26|
# |   U206| 23|
# |   U207| 35|
# |   U208| 40|
# |   U209| 40|
# |   U210| 44|
# |   U211| 33|
# |   U212| 33|
# |   U213| 17|
# |   U214| 31|
# |   U215| 48|
# |   U216| 19|
# |   U217| 48|
# |   U218| 29|
# |   U219| 36|
# |   U220| 35|
# |   U221| 23|
# |   U222| 22|
# |   U223| 18|
# |   U224| 32|
# |   U225| 48|
# |   U226| 27|
# |   U227| 37|
# |   U228| 37|
# |   U229| 45|
# |   U230| 23|
# |   U231| 42|
# |   U232| 42|
# |   U233| 49|
# |   U234| 36|
# |   U235| 45|
# |   U236| 48|
# |   U237| 43|
# |   U238| 48|
# |   U239| 20|
# |   U240| 34|
# |   U241| 19|
# |   U242| 32|
# |   U243| 43|
# |   U244| 45|
# |   U245| 44|
# |   U246| 21|
# |   U247| 39|
# |   U248| 44|
# |   U249| 46|
# |   U250| 48|
# |   U251| 36|
# |   U252| 47|
# |   U253| 38|
# |   U254| 48|
# |   U255| 18|
# |   U256| 33|
# |   U257| 40|
# |   U258| 46|
# |   U259| 18|
# |   U260| 39|
# |   U261| 47|
# |   U262| 37|
# |   U263| 38|
# |   U264| 17|
# |   U265| 42|
# |   U266| 17|
# |   U267| 41|
# |   U268| 32|
# |   U269| 48|
# |   U270| 24|
# |   U271| 44|
# |   U272| 41|
# |   U273| 40|
# |   U274| 39|
# |   U275| 28|
# |   U276| 22|
# |   U277| 35|
# |   U278| 16|
# |   U279| 23|
# |   U280| 31|
# |   U281| 29|
# |   U282| 27|
# |   U283| 38|
# |   U284| 30|
# |   U285| 43|
# |   U286| 49|
# |   U287| 17|
# |   U288| 47|
# |   U289| 38|
# |   U290| 37|
# |   U291| 40|
# |   U292| 37|
# |   U293| 37|
# |   U294| 21|
# |   U295| 30|
# |   U296| 48|
# |   U297| 23|
# |   U298| 20|
# |   U299| 19|
# |   U300| 21|
# |   U301| 47|
# |   U302| 45|
# |   U303| 31|
# |   U304| 28|
# |   U305| 45|
# |   U306| 34|
# |   U307| 32|
# |   U308| 34|
# |   U309| 43|
# |   U310| 41|
# |   U311| 41|
# |   U312| 38|
# |   U313| 24|
# |   U314| 27|
# |   U315| 16|
# |   U316| 16|
# |   U317| 49|
# |   U318| 47|
# |   U319| 40|
# |   U320| 16|
# |   U321| 31|
# |   U322| 20|
# |   U323| 37|
# |   U324| 44|
# |   U325| 18|
# |   U326| 27|
# |   U327| 41|
# |   U328| 31|
# |   U329| 37|
# |   U330| 44|
# |   U331| 29|
# |   U332| 43|
# |   U333| 20|
# |   U334| 45|
# |   U335| 20|
# |   U336| 27|
# |   U337| 31|
# |   U338| 41|
# |   U339| 41|
# |   U340| 36|
# |   U341| 48|
# |   U342| 45|
# |   U343| 38|
# |   U344| 25|
# |   U345| 20|
# |   U346| 49|
# |   U347| 46|
# |   U348| 25|
# |   U349| 34|
# |   U350| 47|
# |   U351| 16|
# |   U352| 20|
# |   U353| 19|
# |   U354| 31|
# |   U355| 39|
# |   U356| 31|
# |   U357| 17|
# |   U358| 43|
# |   U359| 47|
# |   U360| 42|
# |   U361| 35|
# |   U362| 39|
# |   U363| 27|
# |   U364| 48|
# |   U365| 48|
# |   U366| 27|
# |   U367| 18|
# |   U368| 16|
# |   U369| 48|
# |   U370| 25|
# |   U371| 44|
# |   U372| 28|
# |   U373| 27|
# |   U374| 46|
# |   U375| 17|
# |   U376| 38|
# |   U377| 32|
# |   U378| 41|
# |   U379| 23|
# |   U380| 44|
# |   U381| 41|
# |   U382| 25|
# |   U383| 41|
# |   U384| 49|
# |   U385| 22|
# |   U386| 19|
# |   U387| 26|
# |   U388| 44|
# |   U389| 40|
# |   U390| 36|
# |   U391| 25|
# |   U392| 24|
# |   U393| 39|
# |   U394| 33|
# |   U395| 47|
# |   U396| 39|
# |   U397| 38|
# |   U398| 47|
# |   U399| 27|
# |   U400| 28|
# |   U401| 38|
# |   U402| 40|
# |   U403| 45|
# |   U404| 32|
# |   U405| 35|
# |   U406| 40|
# |   U407| 37|
# |   U408| 28|
# |   U409| 34|
# |   U410| 27|
# |   U411| 34|
# |   U412| 27|
# |   U413| 24|
# |   U414| 22|
# |   U415| 43|
# |   U416| 29|
# |   U417| 46|
# |   U418| 34|
# |   U419| 31|
# |   U420| 20|
# |   U421| 27|
# |   U422| 40|
# |   U423| 36|
# |   U424| 38|
# |   U425| 31|
# |   U426| 29|
# |   U427| 46|
# |   U428| 20|
# |   U429| 38|
# |   U430| 44|
# |   U431| 26|
# |   U432| 33|
# |   U433| 27|
# |   U434| 24|
# |   U435| 25|
# |   U436| 32|
# |   U437| 22|
# |   U438| 28|
# |   U439| 24|
# |   U440| 42|
# |   U441| 17|
# |   U442| 20|
# |   U443| 44|
# |   U444| 34|
# |   U445| 23|
# |   U446| 16|
# |   U447| 37|
# |   U448| 32|
# |   U449| 22|
# |   U450| 40|
# |   U451| 19|
# |   U452| 21|
# |   U453| 46|
# |   U454| 34|
# |   U455| 42|
# |   U456| 25|
# |   U457| 41|
# |   U458| 34|
# |   U459| 18|
# |   U460| 28|
# |   U461| 43|
# |   U462| 35|
# |   U463| 43|
# |   U464| 23|
# |   U465| 16|
# |   U466| 18|
# |   U467| 28|
# |   U468| 43|
# |   U469| 40|
# |   U470| 48|
# |   U471| 21|
# |   U472| 47|
# |   U473| 36|
# |   U474| 31|
# |   U475| 36|
# |   U476| 26|
# |   U477| 34|
# |   U478| 35|
# |   U479| 33|
# |   U480| 29|
# |   U481| 30|
# |   U482| 46|
# |   U483| 16|
# |   U484| 18|
# |   U485| 31|
# |   U486| 38|
# |   U487| 26|
# |   U488| 27|
# |   U489| 25|
# |   U490| 47|
# |   U491| 31|
# |   U492| 23|
# |   U493| 27|
# |   U494| 39|
# |   U495| 43|
# |   U496| 23|
# |   U497| 43|
# |   U498| 41|
# |   U499| 23|
# |   U500| 43|
# |   U501| 25|
# +-------+---+

# %%
from pyspark.sql.functions import col

# Example: users with screen time > 5 hrs
df_appended.filter(col("Daily_Screen_Time") > 5).show()
# Out:
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# |User_ID|Age|Gender|Daily_Screen_Time|Sleep_Quality|Stress_Level|Days_Without_Social_Media|Exercise_Frequency|Social_Media_Platform|Happiness_Index|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# |   U002| 30| Other|              5.1|          7.0|         8.0|                      5.0|               3.0|             LinkedIn|           10.0|
# |   U003| 23| Other|              7.4|          6.0|         7.0|                      1.0|               3.0|              YouTube|            6.0|
# |   U004| 36|Female|              5.7|          7.0|         8.0|                      1.0|               1.0|               TikTok|            8.0|
# |   U005| 34|Female|              7.0|          4.0|         7.0|                      5.0|               1.0|          X (Twitter)|            8.0|
# |   U006| 38|  Male|              6.6|          5.0|         7.0|                      4.0|               3.0|             LinkedIn|            8.0|
# |   U007| 26|Female|              7.8|          4.0|         8.0|                      2.0|               0.0|               TikTok|            7.0|
# |   U008| 26|Female|              7.4|          5.0|         6.0|                      1.0|               4.0|            Instagram|            7.0|
# |   U010| 39|Female|              6.6|          6.0|         8.0|                      0.0|               2.0|             Facebook|            7.0|
# |   U012| 37| Other|              5.4|          5.0|         7.0|                      3.0|               2.0|            Instagram|            9.0|
# |   U013| 17|Female|              7.0|          7.0|        10.0|                      7.0|               1.0|              YouTube|            8.0|
# |   U014| 39|Female|              5.7|          5.0|         7.0|                      4.0|               0.0|             Facebook|            8.0|
# |   U015| 45|  Male|              6.3|          7.0|         7.0|                      4.0|               3.0|          X (Twitter)|            9.0|
# |   U016| 17|Female|              5.1|          7.0|         6.0|                      2.0|               5.0|             LinkedIn|           10.0|
# |   U017| 36|Female|              7.5|          5.0|         8.0|                      4.0|               4.0|             Facebook|            7.0|
# |   U018| 48|  Male|              5.4|          6.0|         4.0|                      3.0|               4.0|               TikTok|           10.0|
# |   U020| 37|  Male|              7.1|          6.0|         6.0|                      5.0|               4.0|               TikTok|           10.0|
# |   U022| 42| Other|              6.4|          7.0|         6.0|                      5.0|               3.0|               TikTok|           10.0|
# |   U024| 31|Female|              7.8|          5.0|         8.0|                      1.0|               2.0|               TikTok|            7.0|
# |   U026| 18| Other|              5.7|          6.0|         7.0|                      3.0|               2.0|          X (Twitter)|            8.0|
# |   U027| 22|Female|              6.2|          5.0|         8.0|                      5.0|               0.0|          X (Twitter)|            6.0|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import avg

df_appended.groupBy("Gender").agg(avg("Daily_Screen_Time")).show()
# Out:
# +------+----------------------+
# |Gender|avg(Daily_Screen_Time)|
# +------+----------------------+
# |Female|     5.512227074235809|
# | Other|     5.065217391304347|
# |  Male|     5.575100401606428|
# +------+----------------------+

# %%
from pyspark.sql.functions import when, col

df_updated = df.withColumn(
    "Happiness_Index",
    when(col("Social_Media_Platform") == "X (Twitter)", col("Happiness_Index") + 1)
    .otherwise(col("Happiness_Index"))
)

df_updated.show()
# Out:
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# |User_ID|Age|Gender|Daily_Screen_Time|Sleep_Quality|Stress_Level|Days_Without_Social_Media|Exercise_Frequency|Social_Media_Platform|Happiness_Index|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# |   U001| 44|  Male|              3.1|          7.0|         6.0|                      2.0|               5.0|             Facebook|           10.0|
# |   U002| 30| Other|              5.1|          7.0|         8.0|                      5.0|               3.0|             LinkedIn|           10.0|
# |   U003| 23| Other|              7.4|          6.0|         7.0|                      1.0|               3.0|              YouTube|            6.0|
# |   U004| 36|Female|              5.7|          7.0|         8.0|                      1.0|               1.0|               TikTok|            8.0|
# |   U005| 34|Female|              7.0|          4.0|         7.0|                      5.0|               1.0|          X (Twitter)|            9.0|
# |   U006| 38|  Male|              6.6|          5.0|         7.0|                      4.0|               3.0|             LinkedIn|            8.0|
# |   U007| 26|Female|              7.8|          4.0|         8.0|                      2.0|               0.0|               TikTok|            7.0|
# |   U008| 26|Female|              7.4|          5.0|         6.0|                      1.0|               4.0|            Instagram|            7.0|
# |   U009| 39|  Male|              4.7|          7.0|         7.0|                      6.0|               1.0|              YouTube|            9.0|
# |   U010| 39|Female|              6.6|          6.0|         8.0|                      0.0|               2.0|             Facebook|            7.0|
# |   U011| 18|Female|              2.8|          7.0|         6.0|                      2.0|               0.0|            Instagram|            7.0|
# |   U012| 37| Other|              5.4|          5.0|         7.0|                      3.0|               2.0|            Instagram|            9.0|
# |   U013| 17|Female|              7.0|          7.0|        10.0|                      7.0|               1.0|              YouTube|            8.0|
# |   U014| 39|Female|              5.7|          5.0|         7.0|                      4.0|               0.0|             Facebook|            8.0|
# |   U015| 45|  Male|              6.3|          7.0|         7.0|                      4.0|               3.0|          X (Twitter)|           10.0|
# |   U016| 17|Female|              5.1|          7.0|         6.0|                      2.0|               5.0|             LinkedIn|           10.0|
# |   U017| 36|Female|              7.5|          5.0|         8.0|                      4.0|               4.0|             Facebook|            7.0|
# |   U018| 48|  Male|              5.4|          6.0|         4.0|                      3.0|               4.0|               TikTok|           10.0|
# |   U019| 27|  Male|              4.7|          6.0|         6.0|                      0.0|               2.0|            Instagram|            9.0|
# |   U020| 37|  Male|              7.1|          6.0|         6.0|                      5.0|               4.0|               TikTok|           10.0|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# only showing top 20 rows

# %%
df_deleted = df.filter(col("Age") >= 30)
df_deleted.show()
# Out:
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# |User_ID|Age|Gender|Daily_Screen_Time|Sleep_Quality|Stress_Level|Days_Without_Social_Media|Exercise_Frequency|Social_Media_Platform|Happiness_Index|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# |   U001| 44|  Male|              3.1|          7.0|         6.0|                      2.0|               5.0|             Facebook|           10.0|
# |   U002| 30| Other|              5.1|          7.0|         8.0|                      5.0|               3.0|             LinkedIn|           10.0|
# |   U004| 36|Female|              5.7|          7.0|         8.0|                      1.0|               1.0|               TikTok|            8.0|
# |   U005| 34|Female|              7.0|          4.0|         7.0|                      5.0|               1.0|          X (Twitter)|            8.0|
# |   U006| 38|  Male|              6.6|          5.0|         7.0|                      4.0|               3.0|             LinkedIn|            8.0|
# |   U009| 39|  Male|              4.7|          7.0|         7.0|                      6.0|               1.0|              YouTube|            9.0|
# |   U010| 39|Female|              6.6|          6.0|         8.0|                      0.0|               2.0|             Facebook|            7.0|
# |   U012| 37| Other|              5.4|          5.0|         7.0|                      3.0|               2.0|            Instagram|            9.0|
# |   U014| 39|Female|              5.7|          5.0|         7.0|                      4.0|               0.0|             Facebook|            8.0|
# |   U015| 45|  Male|              6.3|          7.0|         7.0|                      4.0|               3.0|          X (Twitter)|            9.0|
# |   U017| 36|Female|              7.5|          5.0|         8.0|                      4.0|               4.0|             Facebook|            7.0|
# |   U018| 48|  Male|              5.4|          6.0|         4.0|                      3.0|               4.0|               TikTok|           10.0|
# |   U020| 37|  Male|              7.1|          6.0|         6.0|                      5.0|               4.0|               TikTok|           10.0|
# |   U021| 40|Female|              3.0|          8.0|         5.0|                      5.0|               4.0|          X (Twitter)|           10.0|
# |   U022| 42| Other|              6.4|          7.0|         6.0|                      5.0|               3.0|               TikTok|           10.0|
# |   U023| 43|  Male|              3.6|          8.0|         5.0|                      3.0|               1.0|             Facebook|            9.0|
# |   U024| 31|Female|              7.8|          5.0|         8.0|                      1.0|               2.0|               TikTok|            7.0|
# |   U025| 30|  Male|              5.0|          6.0|         6.0|                      0.0|               5.0|          X (Twitter)|            8.0|
# |   U028| 36|Female|              2.0|          8.0|         4.0|                      5.0|               0.0|             Facebook|           10.0|
# |   U030| 33|  Male|              7.4|          6.0|        10.0|                      3.0|               4.0|            Instagram|            8.0|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# only showing top 20 rows

# %%
df_updated.write.mode("overwrite").parquet("mental_health.parquet")

# %%
df_updated.count()
# Out:
# 500

# %%
df.count()
# Out:
# 500

# %%
df_deleted.count()
# Out:
# 306

# %%
## df.orderBy("Age").show()
df.orderBy(col("Age").desc()).show()
# Out:
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# |User_ID|Age|Gender|Daily_Screen_Time|Sleep_Quality|Stress_Level|Days_Without_Social_Media|Exercise_Frequency|Social_Media_Platform|Happiness_Index|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# |   U050| 49|  Male|              3.6|          7.0|         5.0|                      4.0|               1.0|               TikTok|            9.0|
# |   U084| 49|  Male|              7.5|          4.0|         7.0|                      2.0|               4.0|          X (Twitter)|            8.0|
# |   U161| 49|  Male|              5.1|          5.0|         7.0|                      6.0|               3.0|              YouTube|            8.0|
# |   U233| 49|  Male|              6.2|          6.0|         8.0|                      1.0|               3.0|             LinkedIn|            8.0|
# |   U286| 49|  Male|              6.1|          5.0|         6.0|                      4.0|               3.0|             LinkedIn|            9.0|
# |   U317| 49|Female|              5.2|          7.0|         8.0|                      3.0|               2.0|             LinkedIn|            8.0|
# |   U346| 49|  Male|              6.7|          6.0|         8.0|                      1.0|               4.0|            Instagram|            8.0|
# |   U384| 49|  Male|              5.5|          7.0|         5.0|                      5.0|               0.0|            Instagram|           10.0|
# |   U148| 48|  Male|              4.6|          7.0|         5.0|                      2.0|               3.0|               TikTok|           10.0|
# |   U124| 48|  Male|              2.8|          7.0|         5.0|                      5.0|               3.0|              YouTube|           10.0|
# |   U133| 48|  Male|              6.5|          6.0|         8.0|                      3.0|               3.0|               TikTok|            8.0|
# |   U085| 48| Other|              4.0|          7.0|         5.0|                      2.0|               5.0|             LinkedIn|           10.0|
# |   U077| 48|Female|              9.7|          4.0|         8.0|                      5.0|               1.0|             LinkedIn|            5.0|
# |   U166| 48|Female|              8.5|          4.0|        10.0|                      3.0|               3.0|             LinkedIn|            8.0|
# |   U180| 48|  Male|              6.8|          4.0|         7.0|                      4.0|               2.0|              YouTube|            7.0|
# |   U203| 48|Female|             10.0|          3.0|        10.0|                      3.0|               2.0|               TikTok|            4.0|
# |   U215| 48|Female|              6.4|          4.0|         6.0|                      2.0|               3.0|               TikTok|            7.0|
# |   U217| 48|  Male|              3.9|          9.0|         5.0|                      1.0|               0.0|          X (Twitter)|           10.0|
# |   U225| 48|  Male|              7.3|          5.0|         9.0|                      4.0|               4.0|            Instagram|            5.0|
# |   U018| 48|  Male|              5.4|          6.0|         4.0|                      3.0|               4.0|               TikTok|           10.0|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# only showing top 20 rows

# %%
df.filter((col("Age") > 25) & (col("Gender") == "Male")).show()
# Out:
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# |User_ID|Age|Gender|Daily_Screen_Time|Sleep_Quality|Stress_Level|Days_Without_Social_Media|Exercise_Frequency|Social_Media_Platform|Happiness_Index|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# |   U001| 44|  Male|              3.1|          7.0|         6.0|                      2.0|               5.0|             Facebook|           10.0|
# |   U006| 38|  Male|              6.6|          5.0|         7.0|                      4.0|               3.0|             LinkedIn|            8.0|
# |   U009| 39|  Male|              4.7|          7.0|         7.0|                      6.0|               1.0|              YouTube|            9.0|
# |   U015| 45|  Male|              6.3|          7.0|         7.0|                      4.0|               3.0|          X (Twitter)|            9.0|
# |   U018| 48|  Male|              5.4|          6.0|         4.0|                      3.0|               4.0|               TikTok|           10.0|
# |   U019| 27|  Male|              4.7|          6.0|         6.0|                      0.0|               2.0|            Instagram|            9.0|
# |   U020| 37|  Male|              7.1|          6.0|         6.0|                      5.0|               4.0|               TikTok|           10.0|
# |   U023| 43|  Male|              3.6|          8.0|         5.0|                      3.0|               1.0|             Facebook|            9.0|
# |   U025| 30|  Male|              5.0|          6.0|         6.0|                      0.0|               5.0|          X (Twitter)|            8.0|
# |   U030| 33|  Male|              7.4|          6.0|        10.0|                      3.0|               4.0|            Instagram|            8.0|
# |   U032| 40|  Male|              6.0|          6.0|         7.0|                      5.0|               4.0|               TikTok|            7.0|
# |   U041| 29|  Male|              7.2|          5.0|         7.0|                      4.0|               1.0|          X (Twitter)|           10.0|
# |   U042| 32|  Male|              6.1|          5.0|         6.0|                      3.0|               3.0|            Instagram|            7.0|
# |   U049| 41|  Male|              3.7|          8.0|         6.0|                      3.0|               1.0|               TikTok|            9.0|
# |   U050| 49|  Male|              3.6|          7.0|         5.0|                      4.0|               1.0|               TikTok|            9.0|
# |   U059| 31|  Male|              7.6|          5.0|        10.0|                      3.0|               2.0|            Instagram|            6.0|
# |   U060| 33|  Male|              8.4|          4.0|         8.0|                      6.0|               4.0|          X (Twitter)|            7.0|
# |   U061| 39|  Male|              2.7|          9.0|         5.0|                      1.0|               3.0|               TikTok|           10.0|
# |   U065| 30|  Male|              6.5|          4.0|         9.0|                      4.0|               3.0|               TikTok|            5.0|
# |   U067| 40|  Male|              4.6|          7.0|         6.0|                      2.0|               1.0|              YouTube|           10.0|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import avg, max, min

df.groupBy("Gender").agg(
    avg("Daily_Screen_Time"),
    max("Sleep_Quality"),
    min("Stress_Level")
).show()
# Out:
# +------+----------------------+------------------+-----------------+
# |Gender|avg(Daily_Screen_Time)|max(Sleep_Quality)|min(Stress_Level)|
# +------+----------------------+------------------+-----------------+
# |Female|     5.512227074235809|              10.0|              2.0|
# | Other|     5.065217391304347|               9.0|              3.0|
# |  Male|      5.58951612903226|              10.0|              3.0|
# +------+----------------------+------------------+-----------------+

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import rank

w = Window.partitionBy(col("Gender")).orderBy(col("Daily_Screen_Time").desc())

df_ranked = df.withColumn("Rank", rank().over(w))
df_ranked.show()
# Out:
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+----+
# |User_ID|Age|Gender|Daily_Screen_Time|Sleep_Quality|Stress_Level|Days_Without_Social_Media|Exercise_Frequency|Social_Media_Platform|Happiness_Index|Rank|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+----+
# |   U249| 46|Female|             10.8|          5.0|        10.0|                      2.0|               3.0|            Instagram|            4.0|   1|
# |   U203| 48|Female|             10.0|          3.0|        10.0|                      3.0|               2.0|               TikTok|            4.0|   2|
# |   U213| 17|Female|              9.8|          4.0|         9.0|                      5.0|               0.0|             LinkedIn|            6.0|   3|
# |   U057| 38|Female|              9.7|          3.0|         9.0|                      3.0|               2.0|             Facebook|            4.0|   4|
# |   U077| 48|Female|              9.7|          4.0|         8.0|                      5.0|               1.0|             LinkedIn|            5.0|   4|
# |   U441| 17|Female|              9.5|          4.0|         9.0|                      2.0|               2.0|              YouTube|            4.0|   6|
# |   U476| 26|Female|              9.3|          3.0|         8.0|                      2.0|               1.0|             Facebook|            6.0|   7|
# |   U338| 41|Female|              9.1|          4.0|         9.0|                      4.0|               2.0|            Instagram|            7.0|   8|
# |   U480| 29|Female|              9.0|          4.0|        10.0|                      3.0|               3.0|               TikTok|            4.0|   9|
# |   U231| 42|Female|              8.8|          4.0|         8.0|                      1.0|               1.0|             LinkedIn|            6.0|  10|
# |   U437| 22|Female|              8.8|          2.0|         9.0|                      4.0|               2.0|             Facebook|            7.0|  10|
# |   U216| 19|Female|              8.7|          6.0|         7.0|                      5.0|               3.0|              YouTube|           10.0|  12|
# |   U482| 46|Female|              8.6|          4.0|         8.0|                      2.0|               2.0|              YouTube|            4.0|  13|
# |   U166| 48|Female|              8.5|          4.0|        10.0|                      3.0|               3.0|             LinkedIn|            8.0|  14|
# |   U489| 25|Female|              8.4|          5.0|         9.0|                      1.0|               3.0|             Facebook|            7.0|  15|
# |   U112| 22|Female|              8.3|          5.0|        10.0|                      0.0|               2.0|            Instagram|            6.0|  16|
# |   U451| 19|Female|              8.1|          5.0|         9.0|                      1.0|               5.0|          X (Twitter)|            7.0|  17|
# |   U273| 40|Female|              8.0|          5.0|         8.0|                      3.0|               3.0|               TikTok|            6.0|  18|
# |   U099| 30|Female|              7.9|          5.0|         8.0|                      0.0|               2.0|             LinkedIn|            8.0|  19|
# |   U007| 26|Female|              7.8|          4.0|         8.0|                      2.0|               0.0|               TikTok|            7.0|  20|
# +-------+---+------+-----------------+-------------+------------+-------------------------+------------------+---------------------+---------------+----+
# only showing top 20 rows

# %%
df.groupBy(col("Gender")).pivot("Social_Media_Platform").avg("Stress_Level").show()
# Out:
# +------+-----------------+------------------+------------------+------------------+-----------------+-----------------+
# |Gender|         Facebook|         Instagram|          LinkedIn|            TikTok|      X (Twitter)|          YouTube|
# +------+-----------------+------------------+------------------+------------------+-----------------+-----------------+
# |Female|6.630434782608695| 6.777777777777778|6.4772727272727275|6.5227272727272725|6.583333333333333|          6.71875|
# | Other|              6.0| 7.666666666666667|               7.5| 7.333333333333333|              5.5|6.333333333333333|
# |  Male|6.735294117647059|7.0227272727272725| 6.333333333333333| 6.604166666666667|6.478260869565218|6.621621621621622|
# +------+-----------------+------------------+------------------+------------------+-----------------+-----------------+
